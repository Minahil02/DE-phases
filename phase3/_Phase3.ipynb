# %%
pip install matplotlib

# %% [markdown]
# MATPLOTLIB
# Matplotlib: Matplotlib is a powerful Python library for data visualization.
# It allows you to create plots, charts, and graphs — similar to what you see in Excel but using Python.

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y=[6,7,8,9,10]
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Line")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
names = ["Ali", "Mina", "Zain"]
scores = [85, 90, 78]

# Plot
plt.bar(names, scores)
plt.title("Students' Scores")
plt.ylabel("Score")
plt.show()

# %%
months = ['Jan','Feb','March','April','May','June','July','Aug','Sep','Oct','Nov','Dec']
revenue = [23000,45000,12000,9000,3000,20000,45000,87000,98000,12000,65000,56999]
plt.plot(months,revenue)
plt.xlabel('months')
plt.ylabel('revenue')
plt.title("Monthly revenue")
plt.show()

# %% [markdown]
# Seaborn:Seaborn is a Python data visualization library based on Matplotlib, but it's:
# Easier to use for statistical graphics,
# Prettier and cleaner by default,
# Integrated with Pandas DataFrames,
# Works directly with DataFrames,
# Built-in themes and color palettes,
# Plots like heatmaps, box plots, violin plots, pair plots, histograms, and regression plots

# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'math': [88, 75, 92, 68, 80, 95, 60, 85, 70, 78],
    'science': [92, 85, 89, 74, 88, 94, 65, 90, 72, 84],
    'english': [85, 78, 94, 70, 85, 98, 63, 86, 68, 80],
    'history': [70, 65, 90, 60, 85, 92, 58, 88, 65, 77],
    'computer': [95, 80, 98, 72, 90, 99, 66, 91, 75, 85]
}

df = pd.DataFrame(data)
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# Plotly: Plotly is an open-source data visualization library in Python (and other languages) that allows you to create interactive and dynamic charts, graphs, and dashboards — perfect for data analysis, reporting, and presentations.

# %%
pip install plotly

# %%
import plotly.express as px
import pandas as pd
data = {
    "Month": ["January", "February", "March", "April", "May"],
    "Revenue": [15000, 18000, 12000, 22000, 25000]
}

df = pd.DataFrame(data)
fig = px.bar(df , x = "Month",y="Revenue",title = "Monthly Revenue", color = "Revenue")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Pandas Built-in Plotting: Pandas Built-in Plotting refers to the simple and quick plotting functions available directly within the Pandas library. It allows you to create basic charts (like bar charts, line graphs, histograms, etc.) directly from DataFrames or Series without needing complex setup.

# %% [markdown]
# Power BI (by Microsoft)
# Power BI is a business analytics tool developed by Microsoft. It allows you to connect to various data sources, transform data, and create interactive dashboards and reports.
#
# Tableau:
# Tableau is another powerful data visualization and analytics platform, known for its beautiful visual outputs and drag-and-drop simplicity.
