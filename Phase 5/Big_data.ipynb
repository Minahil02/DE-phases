# %%
pip install pyspark

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ebc1da64-39a8-4281-95b4-8aa6034dd692" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebc1da64-39a8-4281-95b4-8aa6034dd692">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("csv_read").getOrCreate()
df = spark.read.csv("data1.csv", header = True , inferSchema= True)
df.printSchema()
df.show(5)
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- scores: integer (nullable = true)
#  |-- profession: string (nullable = true)
#
# +-------+---+------+----------+
# |   name|age|scores|profession|
# +-------+---+------+----------+
# |minahil| 20|   450|   student|
# |   asma| 22|   460|   teacher|
# |    ali| 21|   300|   student|
# |  ashir| 25|   350|   student|
# |  hamid| 35|   550|   student|
# +-------+---+------+----------+
# only showing top 5 rows

# %%
# !pip install -q pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Even_count").getOrCreate()
sc = spark.sparkContext
rdd = sc.parallelize(range(1,1000))
even = rdd.filter(lambda x: x % 2 == 0 )
even_count = even.count()
print(f"Total even numbers: {even_count}")
# Out:
# Total even numbers: 499

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98af70b9-c5d1-4363-bb97-bc1c42b322fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98af70b9-c5d1-4363-bb97-bc1c42b322fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Groups").getOrCreate()
df = spark.read.csv("data2.csv",header = True, inferSchema=True)
df.printSchema()
result = df.groupBy("region").sum("sales")
result.show()


pandas_df = df.toPandas()
print(pandas_df.head())
# Out:
# root
#  |-- region: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- sales: integer (nullable = true)
#
# +------+----------+
# |region|sum(sales)|
# +------+----------+
# | South|      2000|
# |  East|      1300|
# | North|      1500|
# +------+----------+
#
#   region product  sales
# 0  North  Laptop   1000
# 1  South   Phone    800
# 2  North   Phone    500
# 3   East  Tablet    700
# 4  South  Laptop   1200
